# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1
p=[-2,-1,0,1,2]
q1=[5-x*x for x in p]
q2=[x/5+1 for x in p]
plt.plot(p,q1)
plt.plot(p,q2)
plt.show()

# %%
# 9
x=[0,1,2,3,4]
f=[(4*i // 5) for i in x]
plt.plot(x,f)
plt.show()
# Out:
#   Cell In [10], line 3
#     f=[(4*i mod 5) for i in x]
#         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
